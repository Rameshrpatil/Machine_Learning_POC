# %%
import pandas as pd
from mlxtend.frequent_patterns import fpgrowth, association_rules
from mlxtend.preprocessing import TransactionEncoder

# %%
df=pd.read_csv('../dataset/electronics_sales_transactions.csv')

# %%
transactions =df['Items'].apply(lambda x: x.split(',')).tolist()

# %%
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df = pd.DataFrame(te_ary, columns=te.columns_)

# %%
min_support = 0.3  # minimum support threshold
frequent_itemsets = fpgrowth(df, min_support=min_support, use_colnames=True)

# %%
frequent_itemsets
# Out:
#     support                           itemsets
# 0    0.6387                       (headphones)
# 1    0.6285                           (laptop)
# 2    0.6315                          (charger)
# 3    0.6184                       (smartphone)
# 4    0.4291               (laptop, headphones)
# 5    0.4210                  (laptop, charger)
# 6    0.3193      (laptop, charger, headphones)
# 7    0.4250              (charger, headphones)
# 8    0.4213           (smartphone, headphones)
# 9    0.4170               (smartphone, laptop)
# 10   0.4162              (smartphone, charger)
# 11   0.3186   (smartphone, laptop, headphones)
# 12   0.3162  (smartphone, charger, headphones)
# 13   0.3122      (laptop, smartphone, charger)

# %%
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7)

# %%
rules
# Out:
#                  antecedents   consequents  antecedent support  \
# 0          (charger, laptop)  (headphones)              0.4210
# 1       (laptop, headphones)     (charger)              0.4291
# 2      (charger, headphones)      (laptop)              0.4250
# 3       (smartphone, laptop)  (headphones)              0.4170
# 4   (smartphone, headphones)      (laptop)              0.4213
# 5       (laptop, headphones)  (smartphone)              0.4291
# 6      (smartphone, charger)  (headphones)              0.4162
# 7   (smartphone, headphones)     (charger)              0.4213
# 8      (charger, headphones)  (smartphone)              0.4250
# 9       (smartphone, laptop)     (charger)              0.4170
# 10         (charger, laptop)  (smartphone)              0.4210
# 11     (smartphone, charger)      (laptop)              0.4162
#
#     consequent support  support  confidence      lift  leverage  conviction  \
# 0               0.6387   0.3193    0.758432  1.187463  0.050407    1.495647
# 1               0.6315   0.3193    0.744116  1.178330  0.048323    1.440103
# 2               0.6285   0.3193    0.751294  1.195376  0.052187    1.493732
# 3               0.6387   0.3186    0.764029  1.196225  0.052262    1.531119
# 4               0.6285   0.3186    0.756231  1.203231  0.053813    1.523982
# 5               0.6184   0.3186    0.742484  1.200654  0.053245    1.481851
# 6               0.6387   0.3162    0.759731  1.189496  0.050373    1.503731
# 7               0.6315   0.3162    0.750534  1.188494  0.050149    1.477156
# 8               0.6184   0.3162    0.744000  1.203105  0.053380    1.490625
# 9               0.6315   0.3122    0.748681  1.185560  0.048865    1.466264
# 10              0.6184   0.3122    0.741568  1.199172  0.051854    1.476596
# 11              0.6285   0.3122    0.750120  1.193509  0.050618    1.486714
#
#     zhangs_metric
# 0        0.272657
# 1        0.265093
# 2        0.284250
# 3        0.281367
# 4        0.291869
# 5        0.292731
# 6        0.272880
# 7        0.274061
# 8        0.293595
# 9        0.268468
# 10       0.286858
# 11       0.277722
